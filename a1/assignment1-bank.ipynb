# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, root_mean_squared_error
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score, validation_curve, learning_curve,LearningCurveDisplay
from tqdm import tqdm
import os
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import f1_score
import seaborn as sns
import cv2
import time
from typing import Any
import json
import re

# %%
RANDOM_SEED=42
IMAGE_SIZE=(64,64)
COLORS = {
    "kNN": 'red',
    'SVM': 'blue',
    'NN': 'green'
}
DATASET_NAME = "bank-marketing"

# %%
df = pd.read_csv("bank/bank-full.csv",delimiter=';')

# Convert numerical columns to the correct data type
df["age"] = df["age"].astype(int)
df["balance"] = df["balance"].astype(int)
df["day"] = df["day"].astype(int)
df["duration"] = df["duration"].astype(int)
df["campaign"] = df["campaign"].astype(int)
df["pdays"] = df["pdays"].astype(int)
df["previous"] = df["previous"].astype(int)
df["y"] = [0 if y=="no" else 1 for y in df["y"]]

# Separate features and target
X = df.drop(columns=["y"])
y = df["y"]

# Define which columns are numerical and which are categorical
numerical_features = ["age", "balance", "day", "duration", "campaign", "pdays", "previous"]
categorical_features = ["job", "marital", "education", "default", "housing", "loan", "contact", "month", "poutcome"]

# Create a column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numerical_features),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features)
    ]
)

# Create a preprocessing and modeling pipeline
pipeline = Pipeline(steps=[
    ("preprocessor", preprocessor)
])

# Fit and transform the data
X_preprocessed = pipeline.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y, test_size=0.2, random_state=RANDOM_SEED)

# %%
def run_grid_search(estimator, param_grid, X, y):
    grid_search = GridSearchCV(estimator=estimator, param_grid=param_grid, cv=3, scoring="f1_weighted",n_jobs=-1,verbose=3)
    grid_search.fit(X, y)

    # Extract the results from grid search
    results = grid_search.cv_results_
    
    return pd.DataFrame(results)

def run_knn(X, y):
    param_grid = {
        'n_neighbors': [1,3,5,10,25,50, 100],
        'weights': ['uniform', 'distance'],
        'metric': ['euclidean', 'manhattan', 'minkowski']
    }
    knn = KNeighborsClassifier(n_jobs=-1)
    df = run_grid_search(knn, param_grid, X, y)
    return df

def run_nn(X, y):
    param_grid = {
        'hidden_layer_sizes': [(128,),(512,),(1024,),(2048,),(128,128),(512,512),(1024,1024),(2048,2048)],
        'alpha': [0.001, 0.0001],
        'momentum': [0.5, 0.7, 0.9],
        'beta_1': [0.9,0.95,0.99]
    }
    mlp = MLPClassifier(max_iter=2000, random_state=RANDOM_SEED)
    df = run_grid_search(mlp, param_grid, X, y)
    return df

def run_svm(X,y):
    param_grid = {
        "kernel": ['poly', 'rbf', 'sigmoid'],
        'C': [1, 3, 5, 8, 10, 25, 50],
    }
    svm = SVC()
    df = run_grid_search(svm, param_grid, X, y)
    return df

# %%
for name, func in [('kNN', run_knn),('SVM', run_svm),('NN', run_nn),]:
    df = func(X_train, y_train)

    print(f"Best parameters for {name} are \n {df.iloc[0]}")
    df.to_csv(f'{name}-gridsearch-{DATASET_NAME}-{time.time()}.csv',index=False)
# Out:
# Fitting 3 folds for each of 144 candidates, totalling 432 fits
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(128,), momentum=0.5;, score=0.890 total time=  37.8s
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(128,), momentum=0.7;, score=0.890 total time=  37.8s
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(128,), momentum=0.9;, score=0.890 total time=  38.3s
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(128,), momentum=0.7;, score=0.886 total time=  43.0s
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(128,), momentum=0.9;, score=0.886 total time=  43.0s
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(128,), momentum=0.5;, score=0.886 total time=  43.2s
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(128,), momentum=0.9;, score=0.888 total time=  43.5s
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(128,), momentum=0.7;, score=0.888 total time=  43.5s
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(128,), momentum=0.5;, score=0.888 total time=  43.7s
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(512,), momentum=0.5;, score=0.885 total time= 1.5min
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(512,), momentum=0.5;, score=0.889 total time= 1.5min
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(512,), momentum=0.7;, score=0.885 total time= 1.5min
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(512,), momentum=0.7;, score=0.889 total time= 1.5min
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(512,), momentum=0.9;, score=0.889 total time= 1.5min
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(512,), momentum=0.9;, score=0.885 total time= 1.5min
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(512,), momentum=0.5;, score=0.888 total time= 1.8min
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(512,), momentum=0.7;, score=0.888 total time= 1.8min
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(512,), momentum=0.9;, score=0.888 total time= 1.8min
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(1024,), momentum=0.5;, score=0.890 total time= 2.3min
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(1024,), momentum=0.5;, score=0.887 total time= 1.8min
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(1024,), momentum=0.7;, score=0.887 total time= 1.8min
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(1024,), momentum=0.9;, score=0.887 total time= 1.9min
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(1024,), momentum=0.5;, score=0.891 total time= 2.4min
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(1024,), momentum=0.7;, score=0.890 total time= 2.5min
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(1024,), momentum=0.7;, score=0.891 total time= 2.6min
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(1024,), momentum=0.9;, score=0.890 total time= 2.6min
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(1024,), momentum=0.9;, score=0.891 total time= 2.4min
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(128, 128), momentum=0.5;, score=0.886 total time=  37.0s
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(2048,), momentum=0.5;, score=0.891 total time= 3.1min
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(2048,), momentum=0.5;, score=0.891 total time= 2.9min
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(128, 128), momentum=0.5;, score=0.882 total time=  39.2s
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(2048,), momentum=0.5;, score=0.888 total time= 3.2min
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(128, 128), momentum=0.5;, score=0.885 total time=  34.3s
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(128, 128), momentum=0.7;, score=0.886 total time=  37.2s
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(128, 128), momentum=0.7;, score=0.885 total time=  33.8s
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(128, 128), momentum=0.7;, score=0.882 total time=  37.6s
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(128, 128), momentum=0.9;, score=0.886 total time=  36.9s
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(2048,), momentum=0.7;, score=0.891 total time= 3.0min
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(2048,), momentum=0.7;, score=0.891 total time= 2.9min
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(128, 128), momentum=0.9;, score=0.885 total time=  37.7s
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(128, 128), momentum=0.9;, score=0.882 total time=  45.3s
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(2048,), momentum=0.7;, score=0.888 total time= 3.3min
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(2048,), momentum=0.9;, score=0.891 total time= 2.9min
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(2048,), momentum=0.9;, score=0.891 total time= 3.0min
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(2048,), momentum=0.9;, score=0.888 total time= 3.3min
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(512, 512), momentum=0.5;, score=0.891 total time= 2.6min
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(512, 512), momentum=0.7;, score=0.891 total time= 2.6min
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(512, 512), momentum=0.5;, score=0.884 total time= 3.3min
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(512, 512), momentum=0.9;, score=0.891 total time= 2.6min
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(512, 512), momentum=0.7;, score=0.884 total time= 3.4min
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(512, 512), momentum=0.9;, score=0.884 total time= 3.3min
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(512, 512), momentum=0.5;, score=0.892 total time= 4.9min
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(512, 512), momentum=0.7;, score=0.892 total time= 4.9min
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(512, 512), momentum=0.9;, score=0.892 total time= 4.9min
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(1024, 1024), momentum=0.5;, score=0.888 total time=12.1min
# /Users/timlampen/.pyenv/versions/3.12.2/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(1024, 1024), momentum=0.5;, score=0.892 total time=10.3min
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(1024, 1024), momentum=0.7;, score=0.892 total time=10.4min
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(1024, 1024), momentum=0.5;, score=0.887 total time=12.1min
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(1024, 1024), momentum=0.7;, score=0.888 total time=12.1min
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(1024, 1024), momentum=0.7;, score=0.887 total time=12.1min
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(1024, 1024), momentum=0.9;, score=0.892 total time=10.3min
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(1024, 1024), momentum=0.9;, score=0.888 total time=12.1min
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(1024, 1024), momentum=0.9;, score=0.887 total time=12.1min
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(128,), momentum=0.5;, score=0.886 total time=  47.9s
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(128,), momentum=0.5;, score=0.889 total time=  35.6s
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(128,), momentum=0.5;, score=0.888 total time=  30.0s
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(128,), momentum=0.7;, score=0.886 total time=  49.3s
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(128,), momentum=0.7;, score=0.889 total time=  37.6s
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(128,), momentum=0.7;, score=0.888 total time=  29.8s
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(128,), momentum=0.9;, score=0.886 total time=  49.5s
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(128,), momentum=0.9;, score=0.889 total time=  37.9s
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(128,), momentum=0.9;, score=0.888 total time=  30.1s
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(512,), momentum=0.5;, score=0.889 total time= 1.2min
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(512,), momentum=0.5;, score=0.885 total time= 1.4min
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(512,), momentum=0.5;, score=0.890 total time= 1.2min
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(512,), momentum=0.7;, score=0.889 total time= 1.2min
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(512,), momentum=0.7;, score=0.885 total time= 1.4min
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(512,), momentum=0.7;, score=0.890 total time= 1.2min
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(512,), momentum=0.9;, score=0.889 total time= 1.2min
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(512,), momentum=0.9;, score=0.885 total time= 1.4min
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(512,), momentum=0.9;, score=0.890 total time= 1.2min
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(1024,), momentum=0.5;, score=0.889 total time= 1.5min
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(1024,), momentum=0.5;, score=0.888 total time= 1.6min
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(1024,), momentum=0.5;, score=0.894 total time= 1.6min
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(1024,), momentum=0.7;, score=0.889 total time= 1.5min
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(1024,), momentum=0.7;, score=0.888 total time= 1.6min
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(2048, 2048), momentum=0.5;, score=0.886 total time=36.9min
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(1024,), momentum=0.7;, score=0.894 total time= 1.6min
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(1024,), momentum=0.9;, score=0.889 total time= 1.6min
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(1024,), momentum=0.9;, score=0.888 total time= 1.6min
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(1024,), momentum=0.9;, score=0.894 total time= 1.6min
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(2048,), momentum=0.5;, score=0.893 total time= 2.5min
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(2048,), momentum=0.5;, score=0.888 total time= 2.6min
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(2048,), momentum=0.5;, score=0.893 total time= 2.8min
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(2048, 2048), momentum=0.7;, score=0.886 total time=36.3min
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(2048,), momentum=0.7;, score=0.893 total time= 2.6min
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(2048, 2048), momentum=0.5;, score=0.889 total time=38.0min
# [CV 1/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(2048, 2048), momentum=0.9;, score=0.886 total time=36.1min
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(2048,), momentum=0.7;, score=0.888 total time= 2.5min
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(2048,), momentum=0.7;, score=0.893 total time= 2.7min
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(2048, 2048), momentum=0.7;, score=0.889 total time=37.9min
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(2048,), momentum=0.9;, score=0.893 total time= 2.5min
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(128, 128), momentum=0.5;, score=0.885 total time=  29.3s
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(128, 128), momentum=0.5;, score=0.885 total time=  29.8s
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(2048,), momentum=0.9;, score=0.888 total time= 2.5min
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(128, 128), momentum=0.7;, score=0.885 total time=  29.9s
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(128, 128), momentum=0.7;, score=0.885 total time=  29.7s
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(128, 128), momentum=0.5;, score=0.888 total time=  45.4s
# [CV 3/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(2048, 2048), momentum=0.9;, score=0.889 total time=37.8min
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(2048,), momentum=0.9;, score=0.893 total time= 2.6min
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(128, 128), momentum=0.9;, score=0.885 total time=  28.3s
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(128, 128), momentum=0.7;, score=0.888 total time=  44.4s
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(128, 128), momentum=0.9;, score=0.885 total time=  30.4s
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(2048, 2048), momentum=0.5;, score=0.892 total time=41.3min
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(128, 128), momentum=0.9;, score=0.888 total time=  44.9s
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(512, 512), momentum=0.5;, score=0.886 total time= 2.2min
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(512, 512), momentum=0.7;, score=0.886 total time= 2.2min
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(2048, 2048), momentum=0.7;, score=0.892 total time=42.0min
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(512, 512), momentum=0.5;, score=0.886 total time= 2.8min
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(512, 512), momentum=0.9;, score=0.886 total time= 2.2min
# [CV 2/3] END alpha=0.001, beta_1=0.9, hidden_layer_sizes=(2048, 2048), momentum=0.9;, score=0.892 total time=41.1min
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(512, 512), momentum=0.7;, score=0.886 total time= 2.8min
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(512, 512), momentum=0.9;, score=0.886 total time= 2.8min
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(512, 512), momentum=0.5;, score=0.888 total time= 3.5min
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(512, 512), momentum=0.7;, score=0.888 total time= 3.6min
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(512, 512), momentum=0.9;, score=0.888 total time= 3.6min
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(1024, 1024), momentum=0.5;, score=0.886 total time=10.2min
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(1024, 1024), momentum=0.7;, score=0.886 total time=10.2min
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(1024, 1024), momentum=0.5;, score=0.888 total time=11.1min
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(1024, 1024), momentum=0.9;, score=0.886 total time=10.2min
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(1024, 1024), momentum=0.7;, score=0.888 total time=11.0min
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(1024, 1024), momentum=0.9;, score=0.888 total time=11.1min
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(1024, 1024), momentum=0.5;, score=0.887 total time=13.0min
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(1024, 1024), momentum=0.7;, score=0.887 total time=13.1min
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(1024, 1024), momentum=0.9;, score=0.887 total time=13.1min
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(128,), momentum=0.5;, score=0.888 total time=  34.1s
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(128,), momentum=0.5;, score=0.887 total time=  33.3s
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(128,), momentum=0.5;, score=0.889 total time=  57.8s
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(128,), momentum=0.7;, score=0.888 total time=  32.5s
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(128,), momentum=0.7;, score=0.887 total time=  29.9s
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(128,), momentum=0.7;, score=0.889 total time=  56.8s
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(128,), momentum=0.9;, score=0.888 total time=  33.4s
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(128,), momentum=0.9;, score=0.887 total time=  30.4s
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(128,), momentum=0.9;, score=0.889 total time=  56.3s
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(512,), momentum=0.5;, score=0.887 total time= 1.1min
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(512,), momentum=0.5;, score=0.892 total time= 1.2min
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(512,), momentum=0.5;, score=0.888 total time= 1.1min
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(512,), momentum=0.7;, score=0.887 total time= 1.0min
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(512,), momentum=0.7;, score=0.892 total time= 1.2min
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(512,), momentum=0.7;, score=0.888 total time= 1.1min
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(512,), momentum=0.9;, score=0.887 total time= 1.0min
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(512,), momentum=0.9;, score=0.892 total time= 1.2min
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(512,), momentum=0.9;, score=0.888 total time= 1.1min
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(1024,), momentum=0.5;, score=0.890 total time= 1.7min
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(1024,), momentum=0.5;, score=0.889 total time= 1.6min
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(1024,), momentum=0.5;, score=0.890 total time= 1.9min
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(1024,), momentum=0.7;, score=0.890 total time= 1.6min
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(2048, 2048), momentum=0.5;, score=0.887 total time=33.8min
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(1024,), momentum=0.7;, score=0.889 total time= 1.5min
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(1024,), momentum=0.7;, score=0.890 total time= 1.8min
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(1024,), momentum=0.9;, score=0.890 total time= 1.6min
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(1024,), momentum=0.9;, score=0.889 total time= 1.5min
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(1024,), momentum=0.9;, score=0.890 total time= 1.8min
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(2048,), momentum=0.5;, score=0.889 total time= 2.3min
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(2048,), momentum=0.5;, score=0.890 total time= 1.8min
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(2048,), momentum=0.5;, score=0.893 total time= 2.0min
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(2048, 2048), momentum=0.7;, score=0.887 total time=33.7min
# [CV 1/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(2048, 2048), momentum=0.9;, score=0.887 total time=33.2min
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(2048,), momentum=0.7;, score=0.889 total time= 2.3min
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(2048,), momentum=0.7;, score=0.890 total time= 1.7min
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(2048,), momentum=0.7;, score=0.893 total time= 2.0min
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(2048,), momentum=0.9;, score=0.890 total time= 1.7min
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(128, 128), momentum=0.5;, score=0.885 total time=  40.1s
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(2048,), momentum=0.9;, score=0.889 total time= 2.3min
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(128, 128), momentum=0.5;, score=0.886 total time=  35.4s
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(128, 128), momentum=0.5;, score=0.886 total time=  27.3s
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(2048,), momentum=0.9;, score=0.893 total time= 2.0min
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(128, 128), momentum=0.7;, score=0.886 total time=  27.3s
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(128, 128), momentum=0.7;, score=0.885 total time=  37.9s
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(128, 128), momentum=0.7;, score=0.886 total time=  33.8s
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(128, 128), momentum=0.9;, score=0.885 total time=  37.5s
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(128, 128), momentum=0.9;, score=0.886 total time=  25.7s
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(128, 128), momentum=0.9;, score=0.886 total time=  34.6s
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(512, 512), momentum=0.5;, score=0.885 total time= 2.2min
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(512, 512), momentum=0.5;, score=0.883 total time= 2.1min
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(2048, 2048), momentum=0.5;, score=0.890 total time=40.8min
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(512, 512), momentum=0.7;, score=0.885 total time= 2.2min
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(512, 512), momentum=0.5;, score=0.884 total time= 2.4min
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(2048, 2048), momentum=0.7;, score=0.890 total time=41.4min
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(512, 512), momentum=0.7;, score=0.883 total time= 2.2min
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(512, 512), momentum=0.7;, score=0.884 total time= 2.4min
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(512, 512), momentum=0.9;, score=0.885 total time= 2.2min
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(512, 512), momentum=0.9;, score=0.883 total time= 2.2min
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(512, 512), momentum=0.9;, score=0.884 total time= 2.4min
# [CV 3/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(2048, 2048), momentum=0.9;, score=0.890 total time=40.7min
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(2048, 2048), momentum=0.5;, score=0.886 total time=45.1min
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(2048, 2048), momentum=0.7;, score=0.886 total time=44.3min
# [CV 2/3] END alpha=0.001, beta_1=0.95, hidden_layer_sizes=(2048, 2048), momentum=0.9;, score=0.886 total time=44.4min
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(1024, 1024), momentum=0.5;, score=0.885 total time= 7.6min
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(1024, 1024), momentum=0.7;, score=0.885 total time= 7.6min
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(1024, 1024), momentum=0.5;, score=0.887 total time=10.0min
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(1024, 1024), momentum=0.9;, score=0.885 total time= 7.6min
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(1024, 1024), momentum=0.5;, score=0.880 total time=10.4min
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(1024, 1024), momentum=0.7;, score=0.887 total time=10.0min
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(1024, 1024), momentum=0.7;, score=0.880 total time=10.5min
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(1024, 1024), momentum=0.9;, score=0.887 total time=10.1min
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(1024, 1024), momentum=0.9;, score=0.880 total time=10.5min
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(128,), momentum=0.5;, score=0.889 total time=  51.2s
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(128,), momentum=0.5;, score=0.887 total time=  52.8s
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(128,), momentum=0.5;, score=0.888 total time=  47.0s
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(128,), momentum=0.7;, score=0.889 total time=  44.9s
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(128,), momentum=0.7;, score=0.887 total time=  50.0s
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(128,), momentum=0.7;, score=0.888 total time=  45.7s
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(128,), momentum=0.9;, score=0.889 total time=  45.2s
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(128,), momentum=0.9;, score=0.887 total time=  49.7s
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(128,), momentum=0.9;, score=0.888 total time=  46.0s
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(512,), momentum=0.5;, score=0.888 total time= 1.6min
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(512,), momentum=0.5;, score=0.886 total time= 1.7min
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(512,), momentum=0.5;, score=0.890 total time= 1.5min
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(512,), momentum=0.7;, score=0.888 total time= 1.6min
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(512,), momentum=0.7;, score=0.886 total time= 1.7min
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(512,), momentum=0.7;, score=0.890 total time= 1.5min
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(512,), momentum=0.9;, score=0.888 total time= 1.7min
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(2048, 2048), momentum=0.5;, score=0.887 total time=24.3min
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(512,), momentum=0.9;, score=0.886 total time= 1.7min
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(2048, 2048), momentum=0.5;, score=0.889 total time=29.5min
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(512,), momentum=0.9;, score=0.890 total time= 1.5min
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(2048, 2048), momentum=0.7;, score=0.887 total time=24.2min
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(1024,), momentum=0.5;, score=0.889 total time= 2.2min
# [CV 3/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(2048, 2048), momentum=0.9;, score=0.887 total time=24.2min
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(1024,), momentum=0.5;, score=0.889 total time= 2.1min
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(1024,), momentum=0.5;, score=0.894 total time= 1.9min
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(1024,), momentum=0.7;, score=0.889 total time= 2.2min
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(1024,), momentum=0.7;, score=0.889 total time= 2.1min
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(1024,), momentum=0.7;, score=0.894 total time= 1.9min
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(2048, 2048), momentum=0.5;, score=0.881 total time=29.3min
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(1024,), momentum=0.9;, score=0.889 total time= 2.1min
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(1024,), momentum=0.9;, score=0.889 total time= 2.1min
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(1024,), momentum=0.9;, score=0.894 total time= 1.9min
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(2048, 2048), momentum=0.7;, score=0.881 total time=28.6min
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(2048, 2048), momentum=0.7;, score=0.889 total time=29.3min
# [CV 1/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(2048, 2048), momentum=0.9;, score=0.889 total time=29.1min
# [CV 2/3] END alpha=0.001, beta_1=0.99, hidden_layer_sizes=(2048, 2048), momentum=0.9;, score=0.881 total time=29.1min
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(2048,), momentum=0.5;, score=0.884 total time= 2.8min
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(2048,), momentum=0.5;, score=0.893 total time= 3.1min
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(128, 128), momentum=0.5;, score=0.882 total time=  37.0s
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(128, 128), momentum=0.5;, score=0.890 total time=  41.8s
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(2048,), momentum=0.5;, score=0.890 total time= 3.6min
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(2048,), momentum=0.7;, score=0.884 total time= 2.7min
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(128, 128), momentum=0.5;, score=0.890 total time=  40.6s
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(128, 128), momentum=0.7;, score=0.882 total time=  35.4s
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(128, 128), momentum=0.7;, score=0.890 total time=  40.9s
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(128, 128), momentum=0.7;, score=0.890 total time=  40.2s
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(128, 128), momentum=0.9;, score=0.890 total time=  41.3s
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(2048,), momentum=0.7;, score=0.890 total time= 3.6min
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(128, 128), momentum=0.9;, score=0.882 total time=  35.1s
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(2048,), momentum=0.7;, score=0.893 total time= 3.1min
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(2048,), momentum=0.9;, score=0.884 total time= 2.7min
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(128, 128), momentum=0.9;, score=0.890 total time=  39.3s
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(2048,), momentum=0.9;, score=0.890 total time= 3.6min
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(2048,), momentum=0.9;, score=0.893 total time= 3.1min
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(512, 512), momentum=0.5;, score=0.891 total time= 3.3min
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(512, 512), momentum=0.7;, score=0.891 total time= 3.3min
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(512, 512), momentum=0.5;, score=0.888 total time= 3.8min
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(512, 512), momentum=0.5;, score=0.890 total time= 3.6min
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(512, 512), momentum=0.9;, score=0.891 total time= 3.3min
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(512, 512), momentum=0.7;, score=0.890 total time= 3.6min
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(512, 512), momentum=0.7;, score=0.888 total time= 3.8min
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(512, 512), momentum=0.9;, score=0.888 total time= 3.9min
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(512, 512), momentum=0.9;, score=0.890 total time= 3.6min
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(1024, 1024), momentum=0.5;, score=0.888 total time=11.2min
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(1024, 1024), momentum=0.5;, score=0.890 total time= 9.9min
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(1024, 1024), momentum=0.7;, score=0.890 total time= 9.8min
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(1024, 1024), momentum=0.9;, score=0.890 total time= 9.8min
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(1024, 1024), momentum=0.7;, score=0.888 total time=11.3min
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(1024, 1024), momentum=0.9;, score=0.888 total time=11.3min
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(1024, 1024), momentum=0.5;, score=0.885 total time=14.7min
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(1024, 1024), momentum=0.7;, score=0.885 total time=14.7min
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(1024, 1024), momentum=0.9;, score=0.885 total time=14.7min
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(128,), momentum=0.5;, score=0.886 total time=  55.2s
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(128,), momentum=0.5;, score=0.887 total time=  33.2s
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(128,), momentum=0.5;, score=0.886 total time=  56.8s
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(128,), momentum=0.7;, score=0.886 total time=  52.1s
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(128,), momentum=0.7;, score=0.887 total time=  30.9s
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(128,), momentum=0.7;, score=0.886 total time=  53.4s
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(128,), momentum=0.9;, score=0.886 total time=  51.3s
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(128,), momentum=0.9;, score=0.887 total time=  32.5s
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(128,), momentum=0.9;, score=0.886 total time=  53.4s
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(512,), momentum=0.5;, score=0.890 total time= 1.5min
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(512,), momentum=0.5;, score=0.888 total time= 1.4min
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(512,), momentum=0.5;, score=0.888 total time= 1.4min
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(512,), momentum=0.7;, score=0.890 total time= 1.5min
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(512,), momentum=0.7;, score=0.888 total time= 1.4min
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(512,), momentum=0.7;, score=0.888 total time= 1.4min
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(512,), momentum=0.9;, score=0.890 total time= 1.4min
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(2048, 2048), momentum=0.5;, score=0.888 total time=31.7min
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(512,), momentum=0.9;, score=0.888 total time= 1.4min
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(512,), momentum=0.9;, score=0.888 total time= 1.4min
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(1024,), momentum=0.5;, score=0.889 total time= 1.8min
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(1024,), momentum=0.5;, score=0.886 total time= 1.9min
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(1024,), momentum=0.5;, score=0.892 total time= 1.8min
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(1024,), momentum=0.7;, score=0.889 total time= 1.8min
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(1024,), momentum=0.7;, score=0.886 total time= 1.9min
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(1024,), momentum=0.7;, score=0.892 total time= 1.8min
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(2048, 2048), momentum=0.5;, score=0.889 total time=32.0min
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(1024,), momentum=0.9;, score=0.889 total time= 1.8min
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(1024,), momentum=0.9;, score=0.886 total time= 1.9min
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(2048, 2048), momentum=0.7;, score=0.888 total time=32.1min
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(1024,), momentum=0.9;, score=0.892 total time= 1.8min
# [CV 1/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(2048, 2048), momentum=0.9;, score=0.888 total time=31.5min
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(2048, 2048), momentum=0.7;, score=0.889 total time=32.5min
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(2048,), momentum=0.5;, score=0.889 total time= 2.8min
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(2048,), momentum=0.5;, score=0.886 total time= 2.8min
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(2048,), momentum=0.5;, score=0.891 total time= 2.5min
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(2048,), momentum=0.7;, score=0.889 total time= 2.8min
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(2048,), momentum=0.7;, score=0.891 total time= 2.5min
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(2048,), momentum=0.7;, score=0.886 total time= 2.8min
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(128, 128), momentum=0.5;, score=0.884 total time=  37.8s
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(128, 128), momentum=0.5;, score=0.884 total time=  47.4s
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(128, 128), momentum=0.5;, score=0.889 total time=  34.3s
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(2048,), momentum=0.9;, score=0.889 total time= 2.8min
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(128, 128), momentum=0.7;, score=0.884 total time=  36.8s
# [CV 2/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(2048, 2048), momentum=0.9;, score=0.889 total time=32.4min
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(128, 128), momentum=0.7;, score=0.889 total time=  33.6s
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(2048,), momentum=0.9;, score=0.891 total time= 2.5min
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(2048,), momentum=0.9;, score=0.886 total time= 2.8min
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(128, 128), momentum=0.7;, score=0.884 total time=  45.7s
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(128, 128), momentum=0.9;, score=0.884 total time=  36.3s
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(128, 128), momentum=0.9;, score=0.889 total time=  34.1s
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(128, 128), momentum=0.9;, score=0.884 total time=  47.1s
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(512, 512), momentum=0.5;, score=0.889 total time= 2.8min
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(512, 512), momentum=0.5;, score=0.882 total time= 3.0min
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(512, 512), momentum=0.5;, score=0.891 total time= 3.1min
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(512, 512), momentum=0.7;, score=0.882 total time= 3.0min
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(512, 512), momentum=0.7;, score=0.889 total time= 2.9min
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(512, 512), momentum=0.7;, score=0.891 total time= 3.2min
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(512, 512), momentum=0.9;, score=0.891 total time= 3.2min
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(512, 512), momentum=0.9;, score=0.889 total time= 2.9min
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(512, 512), momentum=0.9;, score=0.882 total time= 3.0min
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(2048, 2048), momentum=0.5;, score=0.892 total time=43.5min
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(2048, 2048), momentum=0.7;, score=0.892 total time=42.7min
# [CV 3/3] END alpha=0.0001, beta_1=0.9, hidden_layer_sizes=(2048, 2048), momentum=0.9;, score=0.892 total time=42.7min
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(1024, 1024), momentum=0.5;, score=0.890 total time=10.9min
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(1024, 1024), momentum=0.5;, score=0.884 total time=12.6min
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(1024, 1024), momentum=0.7;, score=0.884 total time=12.6min
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(1024, 1024), momentum=0.5;, score=0.888 total time=13.5min
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(1024, 1024), momentum=0.7;, score=0.888 total time=13.5min
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(1024, 1024), momentum=0.7;, score=0.890 total time=10.9min
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(1024, 1024), momentum=0.9;, score=0.890 total time=11.0min
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(1024, 1024), momentum=0.9;, score=0.884 total time=12.7min
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(1024, 1024), momentum=0.9;, score=0.888 total time=13.5min
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(128,), momentum=0.5;, score=0.887 total time=  33.9s
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(128,), momentum=0.5;, score=0.888 total time=  33.9s
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(128,), momentum=0.5;, score=0.889 total time=  38.9s
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(128,), momentum=0.7;, score=0.887 total time=  31.6s
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(128,), momentum=0.7;, score=0.888 total time=  32.3s
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(128,), momentum=0.7;, score=0.889 total time=  39.1s
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(128,), momentum=0.9;, score=0.887 total time=  31.8s
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(128,), momentum=0.9;, score=0.888 total time=  33.9s
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(128,), momentum=0.9;, score=0.889 total time=  38.7s
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(512,), momentum=0.5;, score=0.887 total time= 1.0min
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(512,), momentum=0.5;, score=0.887 total time=  58.3s
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(512,), momentum=0.5;, score=0.888 total time= 3.2min
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(512,), momentum=0.7;, score=0.887 total time= 1.3min
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(512,), momentum=0.7;, score=0.887 total time= 4.1min
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(512,), momentum=0.7;, score=0.888 total time=16.8min
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(512,), momentum=0.9;, score=0.887 total time= 1.7min
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(512,), momentum=0.9;, score=0.887 total time= 2.9min
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(512,), momentum=0.9;, score=0.888 total time= 1.6min
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(1024,), momentum=0.5;, score=0.889 total time= 1.6min
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(1024,), momentum=0.5;, score=0.889 total time= 1.6min
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(1024,), momentum=0.5;, score=0.890 total time= 1.9min
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(2048, 2048), momentum=0.5;, score=0.889 total time=54.1min
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(1024,), momentum=0.7;, score=0.889 total time= 1.6min
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(1024,), momentum=0.7;, score=0.889 total time= 1.6min
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(1024,), momentum=0.7;, score=0.890 total time= 1.9min
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(1024,), momentum=0.9;, score=0.889 total time= 1.6min
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(1024,), momentum=0.9;, score=0.889 total time= 1.6min
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(1024,), momentum=0.9;, score=0.890 total time= 1.9min
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(2048, 2048), momentum=0.7;, score=0.889 total time=53.7min
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(2048,), momentum=0.5;, score=0.887 total time= 2.3min
# [CV 1/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(2048, 2048), momentum=0.9;, score=0.889 total time=54.2min
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(2048,), momentum=0.5;, score=0.891 total time= 2.2min
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(2048, 2048), momentum=0.5;, score=0.884 total time=58.0min
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(2048, 2048), momentum=0.5;, score=0.891 total time=56.7min
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(2048,), momentum=0.5;, score=0.890 total time= 2.5min
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(2048,), momentum=0.7;, score=0.887 total time= 2.3min
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(2048,), momentum=0.7;, score=0.891 total time= 2.1min
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(128, 128), momentum=0.5;, score=0.884 total time=  30.4s
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(128, 128), momentum=0.5;, score=0.881 total time=  34.4s
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(2048, 2048), momentum=0.7;, score=0.891 total time=57.2min
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(2048, 2048), momentum=0.7;, score=0.884 total time=57.6min
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(128, 128), momentum=0.5;, score=0.889 total time=  34.2s
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(128, 128), momentum=0.7;, score=0.884 total time=  29.8s
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(2048,), momentum=0.7;, score=0.890 total time= 2.5min
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(2048,), momentum=0.9;, score=0.887 total time= 2.3min
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(2048,), momentum=0.9;, score=0.891 total time= 2.1min
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(128, 128), momentum=0.7;, score=0.881 total time=  32.7s
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(128, 128), momentum=0.9;, score=0.884 total time=  28.2s
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(128, 128), momentum=0.7;, score=0.889 total time=  33.1s
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(128, 128), momentum=0.9;, score=0.881 total time=  32.6s
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(128, 128), momentum=0.9;, score=0.889 total time=  35.3s
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(2048,), momentum=0.9;, score=0.890 total time= 2.4min
# [CV 3/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(2048, 2048), momentum=0.9;, score=0.891 total time=56.7min
# [CV 2/3] END alpha=0.0001, beta_1=0.95, hidden_layer_sizes=(2048, 2048), momentum=0.9;, score=0.884 total time=57.5min
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(512, 512), momentum=0.5;, score=0.889 total time= 2.3min
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(512, 512), momentum=0.5;, score=0.884 total time= 2.5min
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(512, 512), momentum=0.7;, score=0.889 total time= 2.3min
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(512, 512), momentum=0.7;, score=0.884 total time= 2.5min
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(512, 512), momentum=0.9;, score=0.889 total time= 2.3min
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(512, 512), momentum=0.9;, score=0.884 total time= 2.5min
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(512, 512), momentum=0.5;, score=0.885 total time= 3.2min
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(512, 512), momentum=0.7;, score=0.885 total time= 3.2min
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(512, 512), momentum=0.9;, score=0.885 total time= 3.3min
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(1024, 1024), momentum=0.5;, score=0.882 total time= 7.8min
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(1024, 1024), momentum=0.7;, score=0.882 total time= 7.8min
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(1024, 1024), momentum=0.5;, score=0.891 total time= 8.2min
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(1024, 1024), momentum=0.7;, score=0.891 total time= 8.2min
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(1024, 1024), momentum=0.9;, score=0.882 total time= 7.8min
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(1024, 1024), momentum=0.5;, score=0.886 total time=10.1min
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(1024, 1024), momentum=0.9;, score=0.891 total time= 8.3min
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(1024, 1024), momentum=0.7;, score=0.886 total time=10.2min
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(1024, 1024), momentum=0.9;, score=0.886 total time=10.2min
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(2048, 2048), momentum=0.5;, score=0.884 total time=27.3min
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(2048, 2048), momentum=0.7;, score=0.884 total time=27.1min
# [CV 2/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(2048, 2048), momentum=0.9;, score=0.884 total time=27.1min
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(2048, 2048), momentum=0.5;, score=0.889 total time=29.2min
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(2048, 2048), momentum=0.7;, score=0.889 total time=29.5min
# [CV 3/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(2048, 2048), momentum=0.9;, score=0.889 total time=28.5min
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(2048, 2048), momentum=0.5;, score=0.886 total time=40.5min
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(2048, 2048), momentum=0.9;, score=0.886 total time=37.2min
# [CV 1/3] END alpha=0.0001, beta_1=0.99, hidden_layer_sizes=(2048, 2048), momentum=0.7;, score=0.886 total time=37.9min
# Best parameters for NN are
#  mean_fit_time                                                        41.53393
# std_fit_time                                                         2.684503
# mean_score_time                                                      0.013108
# std_score_time                                                       0.000341
# param_alpha                                                             0.001
# param_beta_1                                                              0.9
# param_hidden_layer_sizes                                               (128,)
# param_momentum                                                            0.5
# params                      {'alpha': 0.001, 'beta_1': 0.9, 'hidden_layer_...
# split0_test_score                                                    0.888021
# split1_test_score                                                    0.885607
# split2_test_score                                                    0.890064
# mean_test_score                                                      0.887897
# std_test_score                                                       0.001822
# rank_test_score                                                            73
# Name: 0, dtype: object

# %%
best_params = {
    "kNN": {'metric':'euclidean', 'n_neighbors':10, 'weights':'distance'},
    "SVM": {'C': 8, 'kernel': "rbf"},
    "NN": {'alpha':0.001, 'beta_1':0.95, 'hidden_layer_sizes':(2048,), 'momentum':0.9},
}

best_models = [
    ('kNN', KNeighborsClassifier(**best_params["kNN"])),
    ('SVM', SVC(**best_params["SVM"])),
    ('NN', MLPClassifier(**best_params["NN"],max_iter=2000))
]
# Begin Learning Curve
learning_output = []
for name, model in best_models:
    train_size_abs, train_scores, test_scores, train_times, test_times = learning_curve(
        model, X_train, y_train, train_sizes=np.linspace(0.1,1,10),cv=5,n_jobs=-1,scoring='f1_weighted', return_times=True
    )
    for train_size, cv_train_scores, cv_test_scores, cv_fit_times, cv_test_times in zip(
        train_size_abs, train_scores, test_scores, train_times, test_times
    ):
        learning_output.append([name, train_size/len(X_train), cv_train_scores.mean(),cv_train_scores.std(), cv_test_scores.mean(), cv_test_scores.std(), cv_fit_times.mean(), cv_fit_times.std(), cv_test_times.mean(),cv_test_times.std()])

learning_output_df = pd.DataFrame(learning_output, columns=["name", "train_size", "train_score", "train_score_std", "test_score", "test_score_std", "train_time", "train_time_std", "test_time", "test_time_std"])
learning_output_df.to_csv(f"learning-output-{DATASET_NAME}-{time.time()}.csv")

# %%
def get_latest_csv_with_prefix(prefix):
    # Define a pattern to match CSV files with the given prefix
    pattern = re.compile(rf'^{prefix}.*\.csv$')
    
    latest_file = None
    latest_time = None

    for filename in os.listdir('.'):
        if pattern.match(filename):
            # Get the timestamp of the file
            timestamp = os.path.getmtime(filename)
            
            # Check if this file has the latest timestamp so far
            if latest_time is None or timestamp > latest_time:
                latest_time = timestamp
                latest_file = filename

    return latest_file

learning_output_df = pd.read_csv(get_latest_csv_with_prefix(f"learning-output-{DATASET_NAME}"))

plt.ylim(0.8,1)
plt.ylabel("F1 Score")
plt.xlabel("Test Size (% Of Input Dataset)")
for name, df in learning_output_df.groupby("name"):
    plt.plot(df["train_size"]*100, df["test_score"], label=f"{name} test score",color=COLORS[name])
    plt.fill_between(df["train_size"]*100, df["test_score"]+df["test_score_std"],df["test_score"]-df["test_score_std"],alpha=0.2,color=COLORS[name])

    plt.plot(df["train_size"]*100, df["train_score"], marker='x', label=f"{name} train score",color=COLORS[name])
    plt.fill_between(df["train_size"]*100, df["train_score"]+df["train_score_std"],df["train_score"]-df["train_score_std"],alpha=0.2,color=COLORS[name])

plt.legend();

# %%
plt.ylabel("Training Time (s)")
plt.xlabel("Test Size (% Of Input Dataset)")
for name, df in learning_output_df.groupby("name"):
    if name not in ("SVM", "NN"):
        continue

    plt.plot(df["train_size"]*100, df["train_time"], label=f"{name}",color=COLORS[name])
    plt.fill_between(df["train_size"]*100, df["train_time"]+df["train_time_std"],df["train_time"]-df["train_time_std"],alpha=0.2,color=COLORS[name])
plt.legend();

# %%
# Begin Validation Curve
def plot_validation_curve(name):
    model_df = pd.read_csv(get_latest_csv_with_prefix(f"{name}-gridsearch-{DATASET_NAME}"))
    model_df['params'] = model_df['params'].apply(lambda x: json.loads(x.replace("'", '"').replace("(", '"(').replace(")", ')"')))

    # Normalize the 'params' column to separate columns
    params_df = pd.json_normalize(model_df['params'])

    # Drop the original 'params' column and merge the new columns
    model_df = model_df.drop(columns=['params']).join(params_df)

    fig, axs = plt.subplots(2, 2, figsize=(10, 8))

    max_i = -1
    for i, (key, value) in enumerate(best_params[name].items()):
        ax = axs.flat[i]
        filtered_df = model_df
        for const_key, const_value in best_params[name].items():
            if const_key==key:
                continue
            if const_key=="hidden_layer_sizes":
                const_value = str(const_value)

            filtered_df = filtered_df[filtered_df[const_key]==const_value]

        ax.set(xlabel=key)
        if key=="hidden_layer_sizes":
            ax.set_xticklabels(filtered_df[key], rotation=45)

        if i % 2==0:
            ax.set(ylabel='Mean F1 Score')

        if filtered_df[key].apply(lambda x: isinstance(x, str)).all():
            ax.bar(filtered_df[key], filtered_df["mean_test_score"], yerr=filtered_df["std_test_score"],capsize=5,color=COLORS[name])
        else:
            ax.plot(filtered_df[key], filtered_df["mean_test_score"], color=COLORS[name])
            ax.fill_between(filtered_df[key], filtered_df["mean_test_score"] + filtered_df["std_test_score"],filtered_df["mean_test_score"] - filtered_df["std_test_score"], color=COLORS[name], alpha=0.2)
        max_i = max(max_i, i)

    for empty_i in range(max_i+1, 4):
        axs.flat[empty_i].axis("off")


plot_validation_curve("kNN")

# %%
plot_validation_curve("SVM")

# %%
plot_validation_curve("NN")
# Out:
# /var/folders/v3/kzkfzr0d6vs5bm72nlpk67_c0000gn/T/ipykernel_85615/2458014992.py:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(filtered_df[key], rotation=45)

# %%
# Final Evaluation

output = []
for name, model in best_models:
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)

    # Calculate the F1 score
    f1 = f1_score(y_test, y_pred, average='weighted')
    output.append([name, f1])

output_df = pd.DataFrame(output, columns=["name", "f1"])

# %%
plt.xlabel("Model")
plt.ylabel("F1 Score")

for _, (name, f1) in output_df.iterrows():
    plt.bar(name, f1, color=COLORS[name]);
